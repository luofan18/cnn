# %% [markdown]
# # Image Captioning with RNNs
# In this exercise you will implement a vanilla recurrent neural networks and use them it to train a model that can generate novel captions for images.

# %%
a = 'today is a good day'
print set(a)
# Out:
# set(['a', ' ', 'd', 'g', 'i', 'o', 's', 't', 'y'])

# %%
run min-char-rnn.py
# Out:
# data has 1022615 characters, 148 unique.
# ----
#  �c�*��s�4�
# s�=�i�v�?�f6 S�DC��9y��
# Gd(���Y��x�OZ�3�RD~�Lfj7�GU���E?p(�5NNn�L��f�IjU(�w�
#
# �l� >u�(���M�K3E-i�����tD��g�Bf�崬,������B�W<:�W��t!���X���!C��68��_(���z�3Nfmb_J0J(k����z��Ae㲟o2�BQC�v�k
# ----
# iter 0, loss: 124.930303
# ----
#  ��U���2�.i3��輥��m�蠥�I��H�襇�����⥇sU��Sl����7�u��ho�ao���
# 襇r���s,���2��g2��h襇 襇it��p磊�襇- ��oo��wd��輥��2��r�������襇l2�� ⥇in���F��rg��p襇2���ea��i襇����hr9 e���rn���t�Bsr��
# ----
# iter 100, loss: 124.704997
# ----
#  loul��CarkidatWcs�oo tyoap ae ofrw Soeia fWytl reke  mraot,Cat
# lt gtf  al.aetdytt yalnnllIaali�st yei rSr yomCretnrria ol r , ya� Itp rttnt l hol ahl iSfreooiant �hf hguw �l rrl nalmo f rif yvo y �
# ----
# iter 200, loss: 121.610743
# ----
#  . uCm ae keeuuue.i,saR dors p shyk toulsoegoee E j a .2lokun ke onwtel ar ttpre .otdm meo foNuuo frs.ontm  hslesmlshr6eXc looolmmnet.le mi  al dok soeddoelsae htn no,xot huo Boek�pwit  kito
# us kslou �
# ----
# iter 300, loss: 117.606802
# ----
#  em hhehgen hep bey bnci?mos Fiynts whn Irr �;xelr vace toudleo �tyfnro fn� aGe, hoyls ang adenhitatll fhe anlhoul a,Wu bhe qe  bly til
# en ilmim aaeutci �ik bruglNwll. fltdnny wu chli btfrko h�ecd lupu
# ----
# iter 400, loss: 113.448157
# ----
#  reg wrltidohdvh�f, onnnenan:vene �bcind Daligowatiblnm  to D-lioer cao uored Telns� dan jth wPe tof cnta An, thtmontheF -o W tyeres Inptiel r intrusmRHowint․arlllDde. me nose todsee Eeylatl te bool
# ----
# iter 500, loss: 109.131620
# ----
#  o, irSrehin h pisitinagrir siS owheor talriteg Yore orke Ste Sutritlat  Ofoiiw ameo lec l ttov huo tieta S iayavrm mor, SMsalamhe wmels ather picm anite atenlanuvf hek aup wis Sorile aaat avtrrtpi
#
# t
# ----
# iter 600, loss: 105.105183
# ----
#  ht thoud SoHtht wul ayie sir riran gh ose op atis red balreti
# t us arginhe nmpe. pae tit wo H ted o whe. Uay porhhe bof atye yo Tot,, uvo Niofoer tod Sai Stlt vem eerve the tf hrae rmie ar of ohiv ofi
# ----
# iter 700, loss: 101.209203
# ----
#   onvesid Banf.
#
# !
#
# coste th doikedak YSwingso po’n Dle Spoom theryt calt hirer,es uagbird yte mie.tOrrtre fonr cor thr linleu �o anth. U6s, Suhe po�epr th Snd Sufo ningit EcVepis Sptad Y�e kptha cw
# ----
# iter 800, loss: 97.547009
# ----
#  lig,.
#
#
# cus tos boond rientoutde cos wiy d anbue thevy sot ftroun syid seu oforile h conpe Ert veed. �urat,it ase the nindg a, Mari bo Youlve he thes weto, adif ncend daly tes cehes f 9antly mhel oave
# ----
# iter 900, loss: 94.202757
# ----
#  hetrtlitlte fes, wes mange Slo thee fowil thed az bamomekmo ave se llunid I fes ghas s.
#
#
#
#
#
#
#
#
#
#
# ag cearhe cealg tarend
#  po dondsnlrel.
# Aj Aie hericde mir1 hay she beey thad awo coraf Eatculngcey cat
# ----
# iter 1000, loss: 90.985736
# ----
#  und whro the td fild tfusleslouther tofe, ovorle dopaveurto atmeat fuhece fhe bed tl e erh wimu m�ohe tho fesanhe ns soiwha che tam cef shea sairh bouf. ofe atd hunston e emoufcis nat �ifer terot/. Sg
# ----
# iter 1100, loss: 88.143666
# ----
#  i ill’sr�Yhayherter avst’y ah. Wisrre’ty. yinlt os iotgdd opr gavisg the -ir�l, he eored biosy meno� yicit pormiwio bung hanve Yatmor o’t�saukk mhimo and sing Howetdedtheot fwirtouEd thad te
# ----
# iter 1200, loss: 85.602209
# ----
#  tret a Thersevet se fang Wherenla th woun eu foo, Yum.
#
#
#
#
# Thill Ca wan. ��Bcoonge,,t gpisreciry beidret at her Yis hari hid Wavo dou hel ho saes g thy Yao Yhe sis ang toron nais Beaun the :os the cat
# ----
# iter 1300, loss: 83.132459
# ----
#  e p orer fto dolide wiavr th toou she.��s roubrn .Th tAYtilige has mad to tat oall. Ao lamd f tre lhen akd oubimp hed wam dit bam suadt hede Taps whe ter. 2rrerolciveub iu a nak tro tiv syoug iodad. o
# ----
# iter 1400, loss: 80.921154
# ----
#  ir.
#
#
# t th
# te pothely’s bispopiges fthirweddu Bet the th oud thal ririthg it d’
#  “tu capoet co, truo turp ha syougis shis hisxd feclond hing fisoiri . Aung Dla hciang, Ta.
#
#
#
#
#
#
#
#
#
#
# hllt.
#
#
#
#
#
# A
# ----
# iter 1500, loss: 78.987631
# ----
#  onssthed foth wame tome f�o tojalcd enleuslged Fhl a tokkal h theuter, Yuo.
#
#
# hed, Hag, inse watelasd led Yaf thes.
#
#
#
#
#
#
#
# Be sins, wolyes tuecerdow  soud Ye theu oud wopiufe Yuh tuwitnrtouneas fuinl
# ----
# iter 1600, loss: 76.987697
# ----
#  s Haslnrten. This rpthehpome bge fas losende she hanoy luoas oowenw. Dalralef hatunig woong Indime the bongreokiins arimeleoucd hedetrerenged oread edederg any oo bicrrot  rio so Yuontntt a led bitlve
# ----
# iter 1700, loss: 75.129396
# ----
#
#
#
# �
# �um puo llliy ang tho duarnd abgad suobto. wy wed to at ave hit perin the thaoti heuf Tea spitW? Uuqtiran abatsv norsd mave nit.ris bs aus baivulmos�wirh bu
#
#
#
# hy eranls Ho santreo*t?’ve �I wo
# ----
# iter 1800, loss: 73.452014
# ----
#  n ons”
# ” cmnaer dirige gste che bayit rosde 3tuble tout thant Ins Bous acive coy ilr! Urf.”
#
#
#
#
# ’s peamdee batrind han pomeOl hentabote renalto cio Youd suh sud hath enctelb okuk alsteso. I me
# ----
# iter 1900, loss: 72.132554
# ----
#  ing. Therishd Yfitennly rinte he the manrean ly ang mo splyerir soad.
# men hrr hpeved mur.u“t asle the isingyy toed cMfoxd ngo ced Dosheco wad suny wo at.
#
#
#
#
#
#
#
#
# �
#
#
#
#
# Hpis jnlar teou so chy orwind
# ----
# iter 2000, loss: 70.715144
# ----
#  f hed tousd heoctlans mon tle rron thigewarer bh woth aouly whalad hehicersme orig, yareatasmed af shaons juoder theakd Yue buta Spihawe tikeo Do oulner pes momed werod dlro garitoate Yuhansrestskan a
# ----
# iter 2100, loss: 69.538498
# ----
#  bit bo ird elte tas Huter thing ang ewaisitainet waof havy fatunge ied. jpbo I flaty ange fon, enn oud tag tuke oed rne th ayd eey bid ovbaled sae uing is foven on hed lo loade pirt tralwyigguvabeleo
# ----
# iter 2200, loss: 68.306094
# ----
#  . Tha nlalrring Wher.“The rref tucad on thom waru wresd ridril hero e’lt. Sasn nle gwalikj it sice iclely the won elked an lof.
# “Hungig tat ancede mighe yalg �, acsers thet, the diglceg seg �ull
# ----
# iter 2300, loss: 67.291881
# ----
#  ouf iy yi peinld mavererdired bime tad lowiny il inyy but royo streday ood ithat gith ecance hris istred. Tl rod wmeo the twous some mas” Subypere dim nure. Exufd, Syit ”
#
#
#
#
# Thaoly yof in m wa aw
# ----
# iter 2400, loss: 66.392488
# ----
#  binde touns eme xpwarme, Af hen he meme am? Uha kuy ectem bo that hel Ia.
#
#
# “niner Eicil Sowe thos woatl anri thoed rot wagd mere par fouis tham focathe ceace aynst lu yeet lamensed thar lingy Hevea
# ----
# iter 2500, loss: 65.523969
# ----
#  or tey. I Hit hou tho tam Yuha ll�.
#
#
#
#
#
# Hurath the.�)th In�os moms But ticglcoulls thaf fe tre pelp o th the doco gid Suthkh nule h io thig the on ttod oted wibe Iit that tho tpoghect ce thly out h
# ----
# iter 2600, loss: 64.944084
# ----
#  troun ot heat ey Salatof enct the to to piwe me; wo apso thartev, Au ceptay tnor kas iak conterruly facat oe iocsroigd, onbetemy thaonthi ouCdengd yobeald alan tisa baving abge ba tres theadas heathy
# ----
# iter 2700, loss: 64.156367
# ----
#  onn, Pede thly meve. fed of toblye taop esnths nuo the melreas balle ave cond mef jgit Bevercanwao thars iny tinbo. Hive wes asp,ek tord tou. Sme the hangang be theinsm bhoy oy mund cat fea kewayd il
# ----
# iter 2800, loss: 63.416063
# ----
#  � wh ot iree eaces. Wisant. Beag Eus spaloug ont ne titk eave inals arco gonse ctamtcuo five a
#
# P mreny wont hir-sontered llmoo thy. I wheut! jy ak old our earw ivelyt there HurBut tot. He spis he poi
# ----
# iter 2900, loss: 62.880414
# ----
#  imarrrsfonagle int thtuo waldy voes e, I midiin ars gilid nterrs ofdrenllirem, te, ere fpirthe raisk, ep deaso whime.
#
#
#
#
#
#
#
# he the thirato tret, asf oanou tasp, endiqus stome hed kee you Spwonge Ders
# ----
# iter 3000, loss: 62.182339
# ----
#  helerilat me outhed ofurit hat gasd.��shlly timy alle d tamo y che.
#
#
#
#
# a’D det theweals lot cat uirs a cosule bm acto fonhigini� an I yo hey ang Its rounh. “�hit oud Bast buce al a yoast ald hpyo
# ----
# iter 3100, loss: 61.352102
# ----
#  nr tot, ro to fobeca wat . It so reanl tond a nmit Yorao wen coc speast ivos go I dee Spirut wat aud. I id yond I rnply iriy’t wave male towire wo mee.
#
#
#
#
# �of ao rnog�� Scen ma toutenr. Af eouds so
# ----
# iter 3200, loss: 60.668542
# ----
#   as, niklorst wrhe wory ald. Thy gpese.
# ’s ar andof tneo yoar. Whom t aed ist ste7  qerpytore?“Witith. go thmeyo thiredt turics vat mpinieg ko. This ixt tolr ived yorond gosed. Hpearicer ir tr ann
# ----
# iter 3300, loss: 60.610876
# ----
#  n wisprouskeding, ae ean ccaningy ar. Yuhi hea yery pingelle spileagg homy aveatel rponstane higg. Hit wisit foith Jukt waiS’t saan.
#
#
#
#
#
#
# Huo hho wowerl�. Aren weas gi�’y bir thaot, eo thecceingt
# ----
# iter 3400, loss: 60.209895
# ----
#  suo tat tiod.
# TWo, Spircevitd ho Yuores ther pirigetly bey staw, Ay wot he haet fas ally arene ghew Ya bircy wily thiriro �ou rouft waigh ally lung out south unt donstof geu aldrertI anse mem. Mou npi
# ----
# iter 3500, loss: 59.804070
# ----
#  te spereD misredeng flelre, anenk ast, hed �ans!terede erhe selteaneware!e nos Then helat, heorenis is crlee for and is re werighe evon’t baon I am, Hmuse ssfoug an. Ar dewect ad walis ind ounnes at
# ----
# iter 3600, loss: 59.314710
# ----
#  p tiy sever, I bednSpif tha se eice wasle waon, per. Ill was “��t, ithesseve heart? Tha son ald land coo reaft cheast ares haulk oud beorg. Smo’t hem the tithu Dor iter. In’t eree fas gorans cin
# ----
# iter 3700, loss: 58.886073
# ----
#   aruld tuls waceigy ? Yte ser ter yowite’t le d,ree erait merntert That Ior ane anwar. yertt galt the stine byy ibin �o the rime wor. Heun aot in celsa thing You in oud trero y tou gor Mo hans tamer
# ----
# iter 3800, loss: 58.548819
# ----
#  mouctaon counlut xoo Yuhadredialdrond, �suly rether in his irland fon Yal. Yker nur bead thau spir, io rinend anoodud alddlicle Donce mabore tha�Y Bearo Bace car yy .oUs canere cocaorg bang hicho lear
# ----
# iter 3900, loss: 58.270571
# ----
#  vycen�e Don taghen, Pas liplevy she chertouTdingtFreredmabethy evern hisg tous gatye,t tow opult ninld thaderd yo. Huo Sp�pithep miropsyoude amtof yule (oinges yoe yfur ang Ythe mive fore the th acey
# ----
# iter 4000, loss: 58.057538
# ----
#
#
# gship, biicde vro thouidod higong seindtteres cour Fea �o�eace thed Mo Yuhey erofl VTa “stive youcwopthi“I had alyd cave fold rit, fou fhe “Tumer yo, nTery rula Xuretio ca ware sefthp acbly hp
# ----
# iter 4100, loss: 57.585323
# ----
#  alcris scretcad inte fereeprild of beafn seil wounde Duck Hul hing anney you tho bed row ao a, bost nachery panunding gorim. I pikesp cese firedring. Thaccoud captharo chis shn ord! uca heris, domlt p
# ----
# iter 4200, loss: 57.499495
# ----
#  ece thuo Sparhe mlthou acd am mere. Hor is spocere honpo forer ander, Mhe apd lespjund Mso mesp berter oly the sealsisad as eiirs arse avanged fon Yue wovett rean thom hew rowad you irhis jisher heute
# ----
# iter 4300, loss: 57.249151
# ----
#  o thing Birk Xland thalnont wingnea Yuhar thostharly Sowale? In a de Spial. Thi
#
#
#
#
# “Yyruus cald mooek Stibest onk on Bees re brom boacd.
#
# Th E�sar ir Spille Drok Bow shak. Sge tofDel., F�st ond kat
# ----
# iter 4400, loss: 57.119097
# ----
#  Ccmile dece. Be sof ir ond bak bas taod,scapthe thals. Asuo dulu asryy hais it ding Beit to Youringe. Bings oup hich iouns. Tha gures-olu s’s, if ta fo waibd bing wingil wath mot hat soed fane titer
# ----
# iter 4500, loss: 56.828496
# ----
#  e lelt har aluth stiad part thed These gime, dpod to bley. Ta tre dfef Wretke, ename los n, tht mpoy hat be reabelt ace sowar on Yu Beike time. Batllite is if sheundy ouy dethen if an‰tit ear.
#
#
#
#
#
#
# ----
# iter 4600, loss: 56.540816
# ----
#  mnori
# d ein ping the the uhthu in* hasp theattrine. I�xth. Thor apmendrs ateen eise ak to the tor of ure this todle and’s fon’s Daper tt out Bad cam a mamere coded chat hazises Bhe tit Huo Yuhili
# ----
# iter 4700, loss: 56.357262
# ----
#   fas his fth Speroutl Baoei a. Thit
#  Beike teibor losed sibe. The kof’t riiled in wakend and deabent Basireot efpysuth hithe ctande. I cophathead ao sullarts Sthird seilg of ar thevelnd eo med pas s
# ----
# iter 4800, loss: 56.085194
# ----
#  ris ant Berpndin*y beimtrist. He bearuld, At sullcect owerive. Afulle sonlm seisglo, aat, an Surturd paged re �hiedy seit git sttpeal he flmeiny tttoeketirt’s beme’e deapad shithif ang Yuhaoun Spa
# ----
# iter 4900, loss: 55.939787
# ----
#  ’t hao Beat areturit Huime olt imse, , Tagg in �stirtine toutis� Toasser hast.
#
#
#
#
#
# Hworarill ihe iy bibbeng andey caifanly poud onars o Dowpont. Theriyd at his etarp holleled ith oween on bousy. It
# ----
# iter 5000, loss: 55.792894
# ----
#  .
#
#
#
#
#
#
#
#
#
#
#
# Povat saxdperurind ow eabeveossencon easser agceake bamaer Sad erorun thitiner gonld hei d hake, bagher an a kaledy qu’t tous Domo codary thom hea dod.”
#
#
#
#
#
#
#
# YIer hakk dis uoo bigel
# ----
# iter 5100, loss: 55.398032
# ----
#   as, nn�an sothattantpy Das ithening yuldirseken Suntirp anter abars at pilligg, thit wauth” Berige agly ttaw Mee ly hat ag Dave bed erp. I thath. H�s Somare a theis. Thit rowhel.”
#
#
#
#
#
# bed Gonpin
# ----
# iter 5200, loss: 55.192029
# ----
#  rrigicaly. Tabliris seibeilinn tou ynable fousd nly’s is thally lon. Lout for yerred Inthing watl pal souibedoud. Awilgomy ceabsorg thad Beulangilninen tana Yah hat feut. I’s inted the deald posin
# ----
# iter 5300, loss: 54.996018
# ----
#  lwe hertw mos waite peickilith. Lulp bow chady in, Savetio Funke the this “Ain aou dut shanave beister heingly backiru lhave Mantircar kxoastleathiin alsee anto ay les and boadive hen the Suvey abTa
# ----
# iter 5400, loss: 54.765702
# ----
#  sceniry the T�nt singils heur Mrowe go Yagh she. An a peancnoi�youon twrou sthesly iburrsangelilk courrtrinn, encand�dyoDdens, to ceire. Mas reag. Fo meilt Yohaod llitho wave s meron to That.
#
#
#
# “��
# ----
# iter 5500, loss: 54.582706
# ----
#   than; tabed chistive yalhand in cumas ritk.�
#  Hiil he tillnter as hem hang �tarning irstelibiles mporet somilng mtille at foveridyo hisboddo Yeithe dis ifqaun. And exdom cofed a�t mastinge.
#
#
#
#
# I”
#
# ----
# iter 5600, loss: 54.443556
# ----
#  ed puirsuld a this was berea gon bod ere aver Hootuong gefentinh, arty of meald hate’s dans, bery hit the. Witn a fyitlye’t slmemy ches ath.
#
#
#
#
#
# Ther Beinicde dref io anid: tho gse berpir, hina s
# ----
# iter 5700, loss: 54.223221
# ----
#  rand thing  i�tling you at pene eves’t ath abinin tret hanter thiu Bermiss alinf. At extr oo steclydedined fyis hor’s to erpgole, fo heitaln ghe casallt eve cle eis dofich. Thing sime hex mus his
# ----
# iter 5800, loss: 54.017791
# ----
#  uh. His Dustir thes creat dingit seict is car bady co pat un Spirit to ghd tly the caitive. Blo cou’s tit io Bao frred in hus chind atungr ind aflo gilly fti
#
#
#
#
#
# Avefere Ya hem yer goudion am focur
# ----
# iter 5900, loss: 53.919198
# ----
#   ilat water oveg cheiln omabaeve cithin youndilnils young beas gar revevion oung.t Spra tle wopled.”
#
#
#
#
#
#
# Bon hlet han’s. Hosung “What ve purild ate,uns be at tsed jiih sugls a pirit we aung to
# ----
# iter 6000, loss: 53.686021
# ----
#  er sheas in hei lyokey sowe evexage, wrougdly a soon’s bugh. Heer he g ist then, Powt ald.
#
#
#
#
#
# Behay pioft sdirit Dan’s bicl hit Hea peard tlXere wyhis ky hacarass Drounine etelnging’s ngden en
# ----
# iter 6100, loss: 53.580208
# ----
#  e laghion jouse of unfospde nouthver ful, Hol Fint explav. Rveming the toadg, Boo Yuhake leat lang lom of hesd erevesing “Huoughent’s Hun a propl extoo somdeald yistene hivever shes ule ald to bel
# ----
# iter 6200, loss: 53.294782
# ----
#  uoas ar Spirith thbomed mewilte ile could bioustemon Couls yout, Coussed Soullittortem aos Dhaclys is irigem uo as ther.”
#
#
#
#
#
# Tam. Ant dale to arde. You ninn “There. Beabuohe mule. Anuti cuiod on
# ----
# iter 6300, loss: 53.326505
# ----
#  suouder owavertetund Heen of apd so the ichoey thas,s ik coulf aos in, sorsant rears.
#
#
#
#
#
# That Hun Skeaced on hyeal gy thetare credere pepseas.
#
#
#
#
#
# The to theine facactound herp onk hhu uo Hued aite
# ----
# iter 6400, loss: 53.442383
# ----
#  ging foupd the shecpiritill eeden. Fuole, ene “he cken Sulribein? Meacs.’s oss stanS oktumy ace ecaves themo thecte Doutiag. An-“Whale clandir’c umpirim.
#
#
#
#
#
# Baye munne w audtead ssark. Noe d
# ----
# iter 6500, loss: 53.327281
# ----
#  curd, d aed wa, whas youisis. An ane nwees ster che piry onsung Sedres ald pase and the thom.
#
#
#
#
#
# ghe ang he werp wars Tals do savan is alon sulpelle font, Suns. qonce isi wart sunt gly erters explio
# ----
# iter 6600, loss: 53.207598
# ----
#  e the so derfor of hure lfen. W� wre the dmes roft an ben ontste ghent co cacter. Ormed iy tame las geded the theice yoo Yuhrit recmed thatawt tharhar kack sunale tho bertery entse axly foure a� Meche
# ----
# iter 6700, loss: 52.923979
# ----
#  iflarm, The seicath akdescdafonsing buois euedof sune lhen th the thert bert to tho bled yeler, Sule, fo alster ald rely and bale thonghe. En fnandred meltsreaster becrevo coo thes yoasinh Dwrest as b
# ----
# iter 6800, loss: 52.939626
# ----
#   ey mecuidet cememnont mo t ixpot “I onle beacget beat bacted leved isteder “�Huo skide the nis obure ghic orpetot ofaine wasa custe Spars’s mmyem yof tot ill the. In ponsaust prate ta y the the
# ----
# iter 6900, loss: 52.917561
# ----
#  e lacke tser blon a fudly lostir swantht.
#
#
#
#
# Buheide gource sao Yat onss gmey ind theanilnd thin fore doded andert os, his hitse satend �ate.” Eo nome werply fliicad an hit tidl oldd kityild thee,
# ----
# iter 7000, loss: 52.821501
# ----
#  temeny chass exkig: y alt suis, Cthe forot yesk.
#
#
#
#
# tur ont at pire praly yon tronYon, weable worh of ean Huo Yuhalt, you afle alantend, “The fake the his an eittred doo fantinc. The �oaSt. Futhins
# ----
# iter 7100, loss: 52.922207
# ----
#  fundedpy urole hilly of Boheuticunnyo Yuhemoned the wous shad at is Xon’s oh surbcull.”
#
#
#
#
#
#
# �font youghe mal hor, Ther fore Sherh hac of SpiriEwis pan is haotoins If Dond owl tilang yululing thi
# ----
# iter 7200, loss: 53.015463
# ----
#  is owar, the eSsarks is hanty mirispon cales oth hint nouln. Buig shhe ilart of to the Clefully a dyidercaled to werdeait opiren. Yuha I you;d wem Spisand erekire ttiek Purwand iinine. Tath alins I a
# ----
# iter 7300, loss: 52.940049
# ----
#  has feremend, dibabeny sat moun freabnise;y ols nhinde fomo hind lepeade, su stitemce wiXougher the cere an Andoull bet Beige, is an.
#
#
#
#
#
#
# Beidend.
#
#
#
#
# The of streroul� Shast out Fto stine. Ta bace v
# ----
# iter 7400, loss: 52.982713
# ----
#  yt hinnenad. Tirt tho und memelydiriVh a laguro youle wheo the fonporn spror greascrtensirask Coutter thoflend folle buthest blterad year?”
#
#
#
#
# Hn��t meirvenousther wallre weuy scan, Lin Zhen sofang
# ----
# iter 7500, loss: 52.894116
# ----
#   wio Yuhao jusave tit obomo were cinced purram ont Eis caldare wyee obocter wac, io lo firsn momed. Ssallsumeouldld the ever ffread.”
#
#
#
#
#
# Pass the flot abing the men sendecy reals tlibadl ans.
#
#
#
#
#
# ----
# iter 7600, loss: 52.748094
# ----
#  s thetiok sita To theam myoten ond ofs. Timy, becttlighen Eveld.”�Bent. The latted. Hu ghe doen warn hoon de eacle werse scare bober hing thing the abecet al to higg plint her ctill thres thit it hi
# ----
# iter 7700, loss: 52.635824
# ----
#  �
#
#
#
#
#
# Af ot a I and blent whiy the hrte fore fad dealt powillste urrioge sbits, ve weapseme hest tond will dodsilly and a se woule forsadast hig acly mando skowstill. Huiriteciille obicame younth Pow
# ----
# iter 7800, loss: 52.534224
# ----
#  inDs he sendmecteir ontrod, and srotire hors sshaaswingoos yoo gifnauss’t apgung hid if aoding neder te thistheis.
#
#
#
#
# “ATwea nnabcins Mand bitp. Emperta mustivan hat was, he the “he.
#
#
#
#
#
# Afre
# ----
# iter 7900, loss: 52.499077
# ----
#  rkinn adpind quhe coud.�
#
#
#
#
#
#
#
# kall. Ik houonine you and onfrele aglt. Bagh gor thin ofn Huacll ��t hat Domice. It Yuhao foo veorth, The gon’t reping. Evend on. Yuhe toud coulditer, “I souber tho
# ----
# iter 8000, loss: 52.314504
# ----
#
#
#
# “Thing ousing smiln prompckionaf. Hoo Yuhao hirt cant.
#
#
#
#
#
#
# Huo Yuhao gh a speal wat’t yerinding Fink han
#
#
#
#
#
#
# Dovew comem the wanlo mitho dap most the actow con he hit.
#
#
#
#
#
# The wrontt lomes
# ----
# iter 8100, loss: 52.146734
# ----
#  a tirest in favild hang were chatting. Hco this c on ang Dong Dopplyed heno sto sepe to hitorer.”
# Peng tuou�’s wit Dyon mist shilly Yuhao.
#
#
#
#
# tBroudd, ovard mosbof rear right he and his aplsagrot
# ----
# iter 8200, loss: 51.913776
# ----
#   whit wattered aclund tou
# gi
#
#
#
#
#
# hirke�. Wirsevenghed rodabgie singed tho lover iderp. Wocer wasaden Hus has dol wis he ciakeribly wis “I rouch he felauderts.
#
#
# ” 7utabecstimvenday fordevedgetill
# ----
# iter 8300, loss: 51.820996
# ----
#  ngmo sprokeded an be son”
#
#
#
#
#
# “Elalgtery sked ourd Dan mvorsadlis inreace hes land gor wacpis werask Tagtlon Dolung onp birious Beonss. Wiocalaig on sepriegiond wis soaenowas faghise was thit ong
# ----
# iter 8400, loss: 51.598207
# ----
#  . H�o tou wock lea, sled ba the trising has bemked worHugrtabimes heg, wo our a nirit spreaomang ing wancere.” I mantry. Whe tof orang axple tocer Dangt. Yle ey taver bonst oche Skast tuo kace heme
# ----
# iter 8500, loss: 51.413928
# ----
#  benty muste the, Heake al a Yuh ended mitith sirek an.
#
#
#
#
#
# Huo Yailung Dhe ssemayt skemung an hitlept. Migg lin s. I foviad a po ofecattectrouth Dorang thit ir he wiw bugh ausing thatt. Tso wigh out
# ----
# iter 8600, loss: 51.415789
# ----
#   a cswuscoe.
#
#
#
#
#
# And coss ould eenenetar awer aldres, misine dirigg his “hire a calle.” Huo Yurat ant onnll is if and Huo Yuhao wadlkervin Pang, Hrow ofre Begugk. Huo ghed haveod minislit her fak
# ----
# iter 8700, loss: 51.363218
# ----
#  fish he aul Willy thed thou has tot my, hal elstentir a rorin be serade fort heacte pror ding tt beltalivess, rhis vade flhed. Shor’t uwing dont Huo Yuhao sowars didler an pemouln ceretill cous?“A
# ----
# iter 8800, loss: 51.448269
# ----
#  r teader.”
#
#
#
#
#
# urserly ofler hho sercany just of peoky won’s renreld s aidejy at pang wexkite sarithive? Dalcee diy fled was.”
#
#
#
#
# SYoo ebedso at inat. The en’s b?
#
#
#
#
#
# The the tot wit muss.
# ----
# iter 8900, loss: 51.479228
# ----
#   reare thane hark bert somey fomach suandi2t to isasing of heny haidirsed a bah aramet has treld souss hnred chad lemcaney and. Yee neved bongyo, sturaly founp, is is youlder.’t soied lyon a alproag
# ----
# iter 9000, loss: 51.517084
# ----
#  leny aaf iriti.
#
#
#
#
#
#
# Bao sud claaztro nen thao Yuo eas bis afm “ass lon, I
# �
#
#
# It He ulyo annet saaddex, “Who samere the crqation “Eod, I prepenon!t Pon’t end Dad, yoen I pen anede fapltals?�
# ----
# iter 9100, loss: 51.277000
# ----
#   Spilit Porco, eas yoummitemoith uhinewe e’s an popy was hat tione the ttide lat aoun stwer ded Huo roly fatl?”
#
#
#
#
# Jund pace histe, fesh to gang, melse a sofer fuctouiitheet hat share for tul.”
# ----
# iter 9200, loss: 51.135995
# ----
#  ad buk nom, le sprost meare. He roucksed prome aceu firsain win sar nusts an thatrest wath, tober miwfo tsorive pel pyot dhas too sprent ant reapirit spirht whe wing Buter Illedterr,, ander hupsamevir
# ----
# iter 9300, loss: 51.369340
# ----
#  odd thit a cound padt raagood to saflew thou dim has a spiwn Wing wapf swstel thou “Dot thong a pouhe. Aw laon, enptared. I tapl ran nigh. Wittor shing and.u’t wrame’s luop?” eecaver. Zh yhar
# ----
# iter 9400, loss: 51.170964
# ----
#  o a sant shicter still woule tade wosk kist the engcood ban onp’s tou and creld was ifterter wathid of eve filcofoss chowe beate, it cund extitedy.”
#
#
#
#
# Yuhanth. I hoo thouccinataon with 4’s nes
# ----
# iter 9500, loss: 51.361284
# ----
#  g laptiva had beroughid eremonisting. Ith a bing sona tittred to beriy anstere.
#
#
#
#
#
# Tame woighe trevlt eang’t Witer., it Ianes.
#
#
#
#
# Huo Yihaor all i cis limer oulyo vailes thas wan in hacly yon fno
# ----
# iter 9600, loss: 51.252244
# ----
#  k ofl. Nog Gangili roul is abhis onaled ty sherir frourded!” Wargre Zhe bom, “Witeseu imthoucires, baou, 3 shis. In bust.
#
#
#
#
#
# Huo Yuhaigh’t wat medio Yaid shate, g asseyter 7caes, fo pradeadule
# ----
# iter 9700, loss: 50.972251
# ----
#   fufres gpesined the laol I ae tooninioly. Cocancet deisidid. Anters.” foladefinne evere trawe pumind elte wationts lafingaled, e runcild. If cact ancassty shreth hoftisery ad thooesuritich �ithoned
# ----
# iter 9800, loss: 50.965338
# ----
#  n seatsale anpicails. Entho The sennint liy silede ssempel the fulactents ans “Spirhe ak powtirs stanged oss on eanle a wuy las hourass of Spar tatut che onith a hind youling hasp. Hea wivenlit, him
# ----
# iter 9900, loss: 50.847728
# ----
#  Huso to yould os cavet Muve. Whe os dome ryathe this wond rith wastere, yo haol fpoobed toos bvent, thit of has �ou hout myefenter cute atire fivete she ibith, on,an soubak. Yuha ap.”O Yirae. fnrad
# ----
# iter 10000, loss: 50.717705
# ----
#  o pindef it is besemile the the,, “Whou werincadist no busd, Snare blosterd noo Zhakeing besy d an �bibitl if caud gopll ovivilrs dlacter a amest byon Bang �beit tus ithrey hery santire I caig. Ache
# ----
# iter 10100, loss: 50.548226
# ----
#   withtuon axd Shaspe waf Zhver falcufpece tisper dould.
#
#
#
#
# ”
#
#
#
#
#
#
#
# “Hit whas sand yout innackt act to demtoc-up “Alh beatse mpenenisiod if riss ang maraistpe, hio shat co the, by to went ge th
# ----
# iter 10200, loss: 50.368980
# ----
#  uo Yueasul gonas it oo has jope teat Yuhaob qu she stine spaclyo an the emterily unev. Tapo, “The op’s uraond cocho ould mimeing ows.
#
#
#
#
#
#
# here extale tiilobelt buotirg and ofe larke sente Yuush.
# ----
# iter 10300, loss: 50.359884
# ----
#   it pearite. Hoe the prese qalle afper Itet.
#
#
#
#
#
#
# Thour nostly the he of hxacld poy momk on annf axt.
#
#
#
#
# Ans he wespex. Ante mat mesit thet is redifing. The exee pevor blee olaribly letren aisanr. H
# ----
# iter 10400, loss: 50.387503
# ----
#  ad it pigraritionss. �o exdor amen ton a seit.
#
#
#
#
#
# Hat easat! a meal to Dowfle mefifide, but whibomp a wap thao Yusae at inpeu ruirinnis Spirit mere, ead Spires very Spirit Puanadvout anend inded t w
# ----
# iter 10500, loss: 50.295093
# ----
#  libing ut he fnet utancais haf hacoet han
#
#
#
#
#
#
# of clili a silred of hiid thoud and to Yohamey fodcin’s co lefobet ist in bestung som a iter nish ontan. They leste uphan tweultung ablly wis fiyhe sp
# ----
# iter 10600, loss: 50.255755
# ----
#  yoo expar Huuhan Hin yle hie land buisp eyou Ya aind expalisy anthts he ling houp his newloulg culrarmef mithen.
#
#
#
# Ofntale matht, yreae cin Yo Huo Yuhaig.
#
#
#
#
#
#
# “Whim sallved and aud tal� was cuqui
# ----
# iter 10700, loss: 50.167667
# ----
#  wer a canto mes ther iverd of af pprod luth wis mothe, Yu rowere migi. Star gilis to shasting hou oraby llow tulrsthed gare becemdanes wifeough wetele wat?”
#
#
#
#
# Fer tatels you dars walad Dand.
#
#
#
#
#
#
# ----
# iter 10800, loss: 49.980749
# ----
#   facion a keref thassabuidasing pucreviplse thouts tile mity dsangouglo wepecrongiliicho renes teaicite to panrilate forasted tore. ge naqalind nut ot was ate sucharkumactlyt entint.
#
#
#
#
#
# Uself io.”
# ----
# iter 10900, loss: 49.872324
# ----
#  he humk foao tor. The geacann’s ve to mate a fome loalexy to ceat. Inaad. It cud a wandey, “Hom sket it oushulyted pyour tote, “Thi anfle coupuzingo deathoun sathrer bite best.o Ya ranTao nomle
# ----
# iter 11000, loss: 49.822709
# ----
#   cratly. Ulfillo wor with stime you Liskr, when fo Yuo me titteigy dears. Os whoingy ceviteing al. I selild spayilest grie pirgs hao cas eve yo cintery thouge ey ftily gutly on pink chor was it mea. W
# ----
# iter 11100, loss: 49.789479
# ----
#  ad is asntanlith aad a tranly it I stare un the tres I moigey reitter, yealig. Engig. he uplyouctaremy. Fos. Tin’s han yuld thasped. hed wagl the becseiggl I harpiris lechidcterf onet Soid expored s
# ----
# iter 11200, loss: 49.754800
# ----
#  aceg fonce ly’t tuar to sinBeded anlerped of apenes efece spirik ther uecor titin he “The tisly has. Ho peding coubireny to hesterfiderseld alsteon Thath’s gen apsaad feil toe a cterey seile she
# ----
# iter 11300, loss: 49.595272
# ----
#   reched che Lsenlomang how ved dose ssent�oe the furt srofing. Threrrem ateim a peachtul sarp a coisly.
#
#
#
#
#
# “You then to hast of on the reet the hons an itso ale at.
#
#
#
#
#
#
# shis seiveny antutiid len
# ----
# iter 11400, loss: 49.506062
# ----
#   thes a tale.”
#
#
#
#
#
# Huo Yuhait in os onder alsertin gores risle nkencarrted ngime steave Yuore of casre a maze thouis suing tang a waf alls his wat wey whactertaeniss go yoy hes lougd Bat want this
# ----
# iter 11500, loss: 49.473776
# ----
#  factend his soucting sore anrut leat li the on antt suse Doliing owdis apemedde reckithe, theul thale thiw of wele dow. Sher, sten. st whlat mirit coud the everente wing s headity, hou no3d. Heive wak
# ----
# iter 11600, loss: 49.342681
# ----
#  irit oighey havin sheecasser by milles this sad her wis Sustion smound he gity,.
#
#
#
#
#
# Af expeepider hith rither bere aytuoll furparm he. He monet it, thing se lytaotenle comt. Bugh wis shar oft alesat
# ----
# iter 11700, loss: 49.254560
# ----
#   rectartery nok jungive mastednnd his is whut to chescesr ous pingter fadidie to the leboncos, grmnos Suphele roalss that hewery extences.
#
#
#
#
#
# The masty nonginefe Zewess shan beald hur’s casteln fa
# ----
# iter 11800, loss: 49.057613
# ----
#  ighe rosive hidy land. Even foue spirit cuss het yous monHe will. At ppirstoy weang, erve Huiat on porenint ouss yower wis wasthodenis hir.t fpong snise and it bins sundly poved aod eact dis the cseun
# ----
# iter 11900, loss: 48.966433
# ----
#   non heinddine mnyentavs ajd.
#
#
#
#
# Foued seasj his.
#
#
#
#
#
#
# The coul “Sts, to andk extsald buod alpale no spibis thece same keaped, hal the thas onhoung mome blentalr. Ans with of hion oull hed ifad an
# ----
# iter 12000, loss: 48.958732
# ----
#  . Spard thac’t myeless theuplly the bespecerpe tlat pleroven 2 a nrow’s stresarls D-her youed his on, Hue turtiono Yuhlo nof caciled, Anendy ain �on ire on Fsanthe ti san hide thus coulll’t umoe
# ----
# iter 12100, loss: 49.032395
# ----
#   the firs, so pat-Huid onushe you a slivel, heir, Ass asl cict. I swecen snuould if exthasstabn the pimlats an srrtion bedrites dad rids nles hit hles. Elple azey hass. Ant a haepined bofated.
#
#
#
#
# Was
# ----
# iter 12200, loss: 49.042134
# ----
#  te, ighe perlsuing moveln.
#
#
#
#
#
# Huo Yist the paat have, I stimed.
#
#
#
#
#
#
# tLow suur sale us aling celber akadledend wanh madfting Marg Ho wad efesh tho the forsply out was the and Thed execang, monl the
# ----
# iter 12300, loss: 49.054810
# ----
#  .
#
#
#
#
#
# Beromed wtousern huwred on cowar thas had Mus stid tell the Wat were wasterr, “Whcuin wore neigter.
#
#
#
#
#
#
#
# Wam to gung”��s Spive ire nomronty ans. Thease, be pibrosty mofen heicey and tibul
# ----
# iter 12400, loss: 49.196609
# ----
#   re hea. ky wall. Tapt hasgehed ing.
#
#
#
#
#
# Weas hithing, lonf he ftrele Spirie quad hing. To cralomther Yiwl a ageno spiams. Zh urise snoftaone acty hive hey weme wasky the and a so sam ren ap! To ging
# ----
# iter 12500, loss: 49.202758
# ----
#  beey neore. Theld, I to thel earake ghere. Werud he fer chadedondened, Tatt this he. rote oust? Tealyou was, uthich.
#
#
#
#
#
# 9wall the ctolys depleve sirseddy Shurded touler past at anted hadd bravang oa
# ----
# iter 12600, loss: 49.194275
# ----
#  tlo Averidmed cow owi he Spirit Deneno woitenn in that hen Asters, or ainty beter atsty nore thas trot an of terete ghe kicked.
#
#
#
#
#
#
# teat, of to reelr hherrt. Huo Yuhao I her, yould stow wus skice be
# ----
# iter 12700, loss: 49.284683
# ----
#  d tul was onle thaver ot whangred ther, With ardiid dotanly Huo she ale tlop hand relrowink, wouked fout la ticefenc “She hant men nos hasidap, a male a Huo gide gam oun of nerrowro nomf. I helt. At
# ----
# iter 12800, loss: 49.415404
# ----
#  d befalsazyon Ceash of gy wor nucked, mougsty’s cengavet at cadl geed, and tist a colded par fperter co hadins, the, ke, ame was pers. The , �Xhe wor stiribice beeledy if, thedtly danding to but su
# ----
# iter 12900, loss: 49.372612
# ----
#  king. Heal ans, eacty bak. Hou hrious, aveney tueh lang! “I arted so to qucellagh.
#
#
#
#
#
#
# goed cam gt was wast whacke. He pitse thac’s tang Ya pit waid whatriokibereably buongling racated nand frea
# ----
# iter 13000, loss: 49.228613
# ----
#
#
#
#
#
#
# She rin them gy to Yaucy prolked’s. Huh him was you remangiluse haw no shacgd and anlsoel and jis thick wat weanasato un had wesplat sor pant, “Stang pe and goou Yuided lisn fast. Noms quith
# ----
# iter 13100, loss: 49.376987
# ----
#  east factalm slracace ove reat caner yobe ston’s showly if inlawn expor ked, acpattrowa? Huth rfer gitar. Hou neonthm istlen hat biony at hister patte can at oxpevallonbre tereal to youed the acine.
# ----
# iter 13200, loss: 49.522346
# ----
#  he anded iided an starer He thene aon. Anle” Shinted fulat buse bot hacty mis cad med sinst to with hid, The arsed ond 2ectrash, enende ansthiitend Xio thak exadg sad are on ong Yurret espere akl ac
# ----
# iter 13300, loss: 49.543061
# ----
#  rcarroo ligh youd leclstler. Ohar mestann’t , Haus. Thiud titlew’s arple toln-hing Preacubat anr. Joulst cancum beead, weashions whas ef a bon’s fewell dorhe tighing latls.
#
#
#
#
# I pulaodred to’
# ----
# iter 13400, loss: 49.772333
# ----
#  rt ther mthis at in shoit ar? I ming’t in inich acotiony had bitle ougk ast cat is kentrilislld atide on Xiwy swin Shor Spinitl pilf and. Rhav. gucrebed herd. Sthe of a wisthe ated thowe cad hix, ao
# ----
# iter 13500, loss: 49.847759
# ----
#   wiven bong samaond you picse nor berind?”” Fhiist outou fire “And heants. Evens lyoneny froukgy eread and but, a dtibe tits rety ther wang Yuhaea dack exlleno kitt showly. Thishs sarsedy in tha
# ----
# iter 13600, loss: 49.784961
# ----
#  ellt of ret ton rot mene feren’t in urded he on, “I benser word angkeve meanle cemace staven ercacaincormy earstink be�fang this Noweay snsaous rorh lodent kin hio Yuhao sinceld ace cinge. you si
# ----
# iter 13700, loss: 49.488271

# %%
# As usual, a bit of setup

import time, os, json
import numpy as np
import matplotlib.pyplot as plt

from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.rnn_layers import *
from cs231n.captioning_solver import CaptioningSolver
from cs231n.classifiers.rnn import CaptioningRNN
from cs231n.coco_utils import load_coco_data, sample_coco_minibatch, decode_captions
from cs231n.image_utils import image_from_url

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Microsoft COCO
# For this exercise we will use the 2014 release of the [Microsoft COCO dataset](http://mscoco.org/) which has become the standard testbed for image captioning. The dataset consists of 80,000 training images and 40,000 validation images, each annotated with 5 captions written by workers on Amazon Mechanical Turk.
#
# To download the data, change to the `cs231n/datasets` directory and run the script `get_coco_captioning.sh`.
#
# We have preprocessed the data and extracted features for you already. For all images we have extracted features from the fc7 layer of the VGG-16 network pretrained on ImageNet; these features are stored in the files `train2014_vgg16_fc7.h5` and `val2014_vgg16_fc7.h5` respectively. To cut down on processing time and memory requirements, we have reduced the dimensionality of the features from 4096 to 512; these features can be found in the files `train2014_vgg16_fc7_pca.h5` and `val2014_vgg16_fc7_pca.h5`.
#
# The raw images take up a lot of space (nearly 20GB) so we have not included them in the download. However all images are taken from Flickr, and URLs of the training and validation images are stored in the files `train2014_urls.txt` and `val2014_urls.txt` respectively. This allows you to download images on the fly for visualization. Since images are downloaded on-the-fly, **you must be connected to the internet to view images**.
#
# Dealing with strings is inefficient, so we will work with an encoded version of the captions. Each word is assigned an integer ID, allowing us to represent a caption by a sequence of integers. The mapping between integer IDs and words is in the file `coco2014_vocab.json`, and you can use the function `decode_captions` from the file `cs231n/coco_utils.py` to convert numpy arrays of integer IDs back into strings.
#
# There are a couple special tokens that we add to the vocabulary. We prepend a special `<START>` token and append an `<END>` token to the beginning and end of each caption respectively. Rare words are replaced with a special `<UNK>` token (for "unknown"). In addition, since we want to train with minibatches containing captions of different lengths, we pad short captions with a special `<NULL>` token after the `<END>` token and don't compute loss or gradient for `<NULL>` tokens. Since they are a bit of a pain, we have taken care of all implementation details around special tokens for you.
#
# You can load all of the MS-COCO data (captions, features, URLs, and vocabulary) using the `load_coco_data` function from the file `cs231n/coco_utils.py`. Run the following cell to do so:

# %%
# Load COCO data from disk; this returns a dictionary
# We'll work with dimensionality-reduced features for this notebook, but feel
# free to experiment with the original features by changing the flag below.
data = load_coco_data(pca_features=True)

# Print out all the keys and values from the data dictionary
for k, v in data.iteritems():
  if type(v) == np.ndarray:
    print k, type(v), v.shape, v.dtype
  else:
    print k, type(v), len(v)
# Out:
# idx_to_word <type 'list'> 1004
# train_captions <type 'numpy.ndarray'> (400135L, 17L) int32
# val_captions <type 'numpy.ndarray'> (195954L, 17L) int32
# train_image_idxs <type 'numpy.ndarray'> (400135L,) int32
# val_features <type 'numpy.ndarray'> (40504L, 512L) float32
# val_image_idxs <type 'numpy.ndarray'> (195954L,) int32
# train_features <type 'numpy.ndarray'> (82783L, 512L) float32
# train_urls <type 'numpy.ndarray'> (82783L,) |S63
# val_urls <type 'numpy.ndarray'> (40504L,) |S63
# word_to_idx <type 'dict'> 1004

# %% [markdown]
# ## Look at the data
# It is always a good idea to look at examples from the dataset before working with it.
#
# You can use the `sample_coco_minibatch` function from the file `cs231n/coco_utils.py` to sample minibatches of data from the data structure returned from `load_coco_data`. Run the following to sample a small minibatch of training data and show the images and their captions. Running it multiple times and looking at the results helps you to get a sense of the dataset.
#
# Note that we decode the captions using the `decode_captions` function and that we download the images on-the-fly using their Flickr URL, so **you must be connected to the internet to viw images**.

# %%
# Sample a minibatch and show the images and captions
batch_size = 3

captions, features, urls = sample_coco_minibatch(data, batch_size=batch_size)
for i, (caption, url) in enumerate(zip(captions, urls)):
  plt.imshow(image_from_url(url))
  plt.axis('off')
  caption_str = decode_captions(caption, data['idx_to_word'])
  plt.title(caption_str)
  plt.show()

# %% [markdown]
# # Recurrent Neural Networks
# As discussed in lecture, we will use recurrent neural network (RNN) language models for image captioning. The file `cs231n/rnn_layers.py` contains implementations of different layer types that are needed for recurrent neural networks, and the file `cs231n/classifiers/rnn.py` uses these layers to implement an image captioning model.
#
# We will first implement different types of RNN layers in `cs231n/rnn_layers.py`.

# %% [markdown]
# # Vanilla RNN: step forward
# Open the file `cs231n/rnn_layers.py`. This file implements the forward and backward passes for different types of layers that are commonly used in recurrent neural networks.
#
# First implement the function `rnn_step_forward` which implements the forward pass for a single timestep of a vanilla recurrent neural network. After doing so run the following to check your implementation.

# %%
N, D, H = 3, 10, 4

x = np.linspace(-0.4, 0.7, num=N*D).reshape(N, D)
prev_h = np.linspace(-0.2, 0.5, num=N*H).reshape(N, H)
Wx = np.linspace(-0.1, 0.9, num=D*H).reshape(D, H)
Wh = np.linspace(-0.3, 0.7, num=H*H).reshape(H, H)
b = np.linspace(-0.2, 0.4, num=H)

next_h, _ = rnn_step_forward(x, prev_h, Wx, Wh, b)
expected_next_h = np.asarray([
  [-0.58172089, -0.50182032, -0.41232771, -0.31410098],
  [ 0.66854692,  0.79562378,  0.87755553,  0.92795967],
  [ 0.97934501,  0.99144213,  0.99646691,  0.99854353]])

print 'next_h error: ', rel_error(expected_next_h, next_h)

# %% [markdown]
# # Vanilla RNN: step backward
# In the file `cs231n/rnn_layers.py` implement the `rnn_step_backward` function. After doing so run the following to numerically gradient check your implementation. You should see errors less than `1e-8`.

# %%
from cs231n.rnn_layers import rnn_step_forward, rnn_step_backward

N, D, H = 4, 5, 6
x = np.random.randn(N, D)
h = np.random.randn(N, H)
Wx = np.random.randn(D, H)
Wh = np.random.randn(H, H)
b = np.random.randn(H)

out, cache = rnn_step_forward(x, h, Wx, Wh, b)

dnext_h = np.random.randn(*out.shape)

fx = lambda x: rnn_step_forward(x, h, Wx, Wh, b)[0]
fh = lambda prev_h: rnn_step_forward(x, h, Wx, Wh, b)[0]
fWx = lambda Wx: rnn_step_forward(x, h, Wx, Wh, b)[0]
fWh = lambda Wh: rnn_step_forward(x, h, Wx, Wh, b)[0]
fb = lambda b: rnn_step_forward(x, h, Wx, Wh, b)[0]

dx_num = eval_numerical_gradient_array(fx, x, dnext_h)
dprev_h_num = eval_numerical_gradient_array(fh, h, dnext_h)
dWx_num = eval_numerical_gradient_array(fWx, Wx, dnext_h)
dWh_num = eval_numerical_gradient_array(fWh, Wh, dnext_h)
db_num = eval_numerical_gradient_array(fb, b, dnext_h)

dx, dprev_h, dWx, dWh, db = rnn_step_backward(dnext_h, cache)

print 'dx error: ', rel_error(dx_num, dx)
print 'dprev_h error: ', rel_error(dprev_h_num, dprev_h)
print 'dWx error: ', rel_error(dWx_num, dWx)
print 'dWh error: ', rel_error(dWh_num, dWh)
print 'db error: ', rel_error(db_num, db)

# %% [markdown]
# # Vanilla RNN: forward
# Now that you have implemented the forward and backward passes for a single timestep of a vanilla RNN, you will combine these pieces to implement a RNN that process an entire sequence of data.
#
# In the file `cs231n/rnn_layers.py`, implement the function `rnn_forward`. This should be implemented using the `rnn_step_forward` function that you defined above. After doing so run the following to check your implementation. You should see errors less than `1e-7`.

# %%
N, T, D, H = 2, 3, 4, 5

x = np.linspace(-0.1, 0.3, num=N*T*D).reshape(N, T, D)
h0 = np.linspace(-0.3, 0.1, num=N*H).reshape(N, H)
Wx = np.linspace(-0.2, 0.4, num=D*H).reshape(D, H)
Wh = np.linspace(-0.4, 0.1, num=H*H).reshape(H, H)
b = np.linspace(-0.7, 0.1, num=H)

h, _ = rnn_forward(x, h0, Wx, Wh, b)
expected_h = np.asarray([
  [
    [-0.42070749, -0.27279261, -0.11074945,  0.05740409,  0.22236251],
    [-0.39525808, -0.22554661, -0.0409454,   0.14649412,  0.32397316],
    [-0.42305111, -0.24223728, -0.04287027,  0.15997045,  0.35014525],
  ],
  [
    [-0.55857474, -0.39065825, -0.19198182,  0.02378408,  0.23735671],
    [-0.27150199, -0.07088804,  0.13562939,  0.33099728,  0.50158768],
    [-0.51014825, -0.30524429, -0.06755202,  0.17806392,  0.40333043]]])
print 'h error: ', rel_error(expected_h, h)

# %% [markdown]
# # Vanilla RNN: backward
# In the file `cs231n/rnn_layers.py`, implement the backward pass for a vanilla RNN in the function `rnn_backward`. This should run back-propagation over the entire sequence, calling into the `rnn_step_backward` function that you defined above.

# %%
N, D, T, H = 2, 3, 10, 5

x = np.random.randn(N, T, D)
h0 = np.random.randn(N, H)
Wx = np.random.randn(D, H)
Wh = np.random.randn(H, H)
b = np.random.randn(H)

out, cache = rnn_forward(x, h0, Wx, Wh, b)

dout = np.random.randn(*out.shape)

dx, dh0, dWx, dWh, db = rnn_backward(dout, cache)

fx = lambda x: rnn_forward(x, h0, Wx, Wh, b)[0]
fh0 = lambda h0: rnn_forward(x, h0, Wx, Wh, b)[0]
fWx = lambda Wx: rnn_forward(x, h0, Wx, Wh, b)[0]
fWh = lambda Wh: rnn_forward(x, h0, Wx, Wh, b)[0]
fb = lambda b: rnn_forward(x, h0, Wx, Wh, b)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
dh0_num = eval_numerical_gradient_array(fh0, h0, dout)
dWx_num = eval_numerical_gradient_array(fWx, Wx, dout)
dWh_num = eval_numerical_gradient_array(fWh, Wh, dout)
db_num = eval_numerical_gradient_array(fb, b, dout)

print 'dx error: ', rel_error(dx_num, dx)
print 'dh0 error: ', rel_error(dh0_num, dh0)
print 'dWx error: ', rel_error(dWx_num, dWx)
print 'dWh error: ', rel_error(dWh_num, dWh)
print 'db error: ', rel_error(db_num, db)

# %% [markdown]
# # Word embedding: forward
# In deep learning systems, we commonly represent words using vectors. Each word of the vocabulary will be associated with a vector, and these vectors will be learned jointly with the rest of the system.
#
# In the file `cs231n/rnn_layers.py`, implement the function `word_embedding_forward` to convert words (represented by integers) into vectors. Run the following to check your implementation. You should see error around `1e-8`.

# %%
N, T, V, D = 2, 4, 5, 3

x = np.asarray([[0, 3, 1, 2], [2, 1, 0, 3]])
W = np.linspace(0, 1, num=V*D).reshape(V, D)

out, _ = word_embedding_forward(x, W)
expected_out = np.asarray([
 [[ 0.,          0.07142857,  0.14285714],
  [ 0.64285714,  0.71428571,  0.78571429],
  [ 0.21428571,  0.28571429,  0.35714286],
  [ 0.42857143,  0.5,         0.57142857]],
 [[ 0.42857143,  0.5,         0.57142857],
  [ 0.21428571,  0.28571429,  0.35714286],
  [ 0.,          0.07142857,  0.14285714],
  [ 0.64285714,  0.71428571,  0.78571429]]])

print 'out error: ', rel_error(expected_out, out)

# %% [markdown]
# # Word embedding: backward
# Implement the backward pass for the word embedding function in the function `word_embedding_backward`. After doing so run the following to numerically gradient check your implementation. You should see errors less than `1e-11`.

# %%
N, T, V, D = 50, 3, 5, 6

x = np.random.randint(V, size=(N, T))
W = np.random.randn(V, D)

out, cache = word_embedding_forward(x, W)
dout = np.random.randn(*out.shape)
dW = word_embedding_backward(dout, cache)

f = lambda W: word_embedding_forward(x, W)[0]
dW_num = eval_numerical_gradient_array(f, W, dout)

print 'dW error: ', rel_error(dW, dW_num)

# %% [markdown]
# # Temporal Affine layer
# At every timestep we use an affine function to transform the RNN hidden vector at that timestep into scores for each word in the vocabulary. Because this is very similar to the affine layer that you implemented in assignment 2, we have provided this function for you in the `temporal_affine_forward` and `temporal_affine_backward` functions in the file `cs231n/rnn_layers.py`. Run the following to perform numeric gradient checking on the implementation.

# %%
# Gradient check for temporal affine layer
N, T, D, M = 2, 3, 4, 5

x = np.random.randn(N, T, D)
w = np.random.randn(D, M)
b = np.random.randn(M)

out, cache = temporal_affine_forward(x, w, b)

dout = np.random.randn(*out.shape)

fx = lambda x: temporal_affine_forward(x, w, b)[0]
fw = lambda w: temporal_affine_forward(x, w, b)[0]
fb = lambda b: temporal_affine_forward(x, w, b)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
dw_num = eval_numerical_gradient_array(fw, w, dout)
db_num = eval_numerical_gradient_array(fb, b, dout)

dx, dw, db = temporal_affine_backward(dout, cache)

print 'dx error: ', rel_error(dx_num, dx)
print 'dw error: ', rel_error(dw_num, dw)
print 'db error: ', rel_error(db_num, db)

# %% [markdown]
# # Temporal Softmax loss
# In an RNN language model, at every timestep we produce a score for each word in the vocabulary. We know the ground-truth word at each timestep, so we use a softmax loss function to compute loss and gradient at each timestep. We sum the losses over time and average them over the minibatch.
#
# However there is one wrinke: since we operate over minibatches and different captions may have different lengths, we append `<NULL>` tokens to the end of each caption so they all have the same length. We don't want these `<NULL>` tokens to count toward the loss or gradient, so in addition to scores and ground-truth labels our loss function also accepts a `mask` array that tells it which elements of the scores count towards the loss.
#
# Since this is very similar to the softmax loss function you implemented in assignment 1, we have implemented this loss function for you; look at the `temporal_softmax_loss` function in the file `cs231n/rnn_layers.py`.
#
# Run the following cell to sanity check the loss and perform numeric gradient checking on the function.

# %%
# Sanity check for temporal softmax loss
from cs231n.rnn_layers import temporal_softmax_loss

N, T, V = 100, 1, 10

def check_loss(N, T, V, p):
  x = 0.001 * np.random.randn(N, T, V)
  y = np.random.randint(V, size=(N, T))
  mask = np.random.rand(N, T) <= p
  print temporal_softmax_loss(x, y, mask)[0]
  
check_loss(100, 1, 10, 1.0)   # Should be about 2.3
check_loss(100, 10, 10, 1.0)  # Should be about 23
check_loss(5000, 10, 10, 0.1) # Should be about 2.3

# Gradient check for temporal softmax loss
N, T, V = 7, 8, 9

x = np.random.randn(N, T, V)
y = np.random.randint(V, size=(N, T))
mask = (np.random.rand(N, T) > 0.5)

loss, dx = temporal_softmax_loss(x, y, mask, verbose=False)

dx_num = eval_numerical_gradient(lambda x: temporal_softmax_loss(x, y, mask)[0], x, verbose=False)

print 'dx error: ', rel_error(dx, dx_num)

# %% [markdown]
# # RNN for image captioning
# Now that you have implemented the necessary layers, you can combine them to build an image captioning model. Open the file `cs231n/classifiers/rnn.py` and look at the `CaptioningRNN` class.
#
# Implement the forward and backward pass of the model in the `loss` function. For now you only need to implement the case where `cell_type='rnn'` for vanialla RNNs; you will implement the LSTM case later. After doing so, run the following to check your forward pass using a small test case; you should see error less than `1e-10`.

# %%
N, D, W, H = 10, 20, 30, 40
word_to_idx = {'<NULL>': 0, 'cat': 2, 'dog': 3}
V = len(word_to_idx)
T = 13

model = CaptioningRNN(word_to_idx,
          input_dim=D,
          wordvec_dim=W,
          hidden_dim=H,
          cell_type='rnn',
          dtype=np.float64)

# Set all model parameters to fixed values
for k, v in model.params.iteritems():
  model.params[k] = np.linspace(-1.4, 1.3, num=v.size).reshape(*v.shape)

features = np.linspace(-1.5, 0.3, num=(N * D)).reshape(N, D)
captions = (np.arange(N * T) % V).reshape(N, T)

loss, grads = model.loss(features, captions)
expected_loss = 9.83235591003

print 'loss: ', loss
print 'expected loss: ', expected_loss
print 'difference: ', abs(loss - expected_loss)

# %% [markdown]
# Run the following cell to perform numeric gradient checking on the `CaptioningRNN` class; you should errors around `1e-7` or less.

# %%
batch_size = 2
timesteps = 3
input_dim = 4
wordvec_dim = 5
hidden_dim = 6
word_to_idx = {'<NULL>': 0, 'cat': 2, 'dog': 3}
vocab_size = len(word_to_idx)

captions = np.random.randint(vocab_size, size=(batch_size, timesteps))
features = np.random.randn(batch_size, input_dim)

model = CaptioningRNN(word_to_idx,
          input_dim=input_dim,
          wordvec_dim=wordvec_dim,
          hidden_dim=hidden_dim,
          cell_type='rnn',
          dtype=np.float64,
        )

loss, grads = model.loss(features, captions)

for param_name in sorted(grads):
  f = lambda _: model.loss(features, captions)[0]
  param_grad_num = eval_numerical_gradient(f, model.params[param_name], verbose=False, h=1e-6)
  e = rel_error(param_grad_num, grads[param_name])
  print '%s relative error: %e' % (param_name, e)

# %% [markdown]
# # Overfit small data
# Similar to the `Solver` class that we used to train image classification models on the previous assignment, on this assignment we use a `CaptioningSolver` class to train image captioning models. Open the file `cs231n/captioning_solver.py` and read through the `CaptioningSolver` class; it should look very familiar.
#
# Once you have familiarized yourself with the API, run the following to make sure your model overfit a small sample of 100 training examples. You should see losses around 1.

# %%
small_data = load_coco_data(max_train=50)

small_rnn_model = CaptioningRNN(
          cell_type='rnn',
          word_to_idx=data['word_to_idx'],
          input_dim=data['train_features'].shape[1],
          hidden_dim=512,
          wordvec_dim=256,
        )

small_rnn_solver = CaptioningSolver(small_rnn_model, small_data,
           update_rule='adam',
           num_epochs=50,
           batch_size=25,
           optim_config={
             'learning_rate': 5e-3,
           },
           lr_decay=0.95,
           verbose=True, print_every=10,
         )

small_rnn_solver.train()

# Plot the training losses
plt.plot(small_rnn_solver.loss_history)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# # Test-time sampling
# Unlike classification models, image captioning models behave very differently at training time and at test time. At training time, we have access to the ground-truth caption so we feed ground-truth words as input to the RNN at each timestep. At test time, we sample from the distribution over the vocabulary at each timestep, and feed the sample as input to the RNN at the next timestep.
#
# In the file `cs231n/classifiers/rnn.py`, implement the `sample` method for test-time sampling. After doing so, run the following to sample from your overfit model on both training and validation data. The samples on training data should be very good; the samples on validation data probably won't make sense.

# %%
for split in ['train', 'val']:
  minibatch = sample_coco_minibatch(small_data, split=split, batch_size=2)
  gt_captions, features, urls = minibatch
  gt_captions = decode_captions(gt_captions, data['idx_to_word'])

  sample_captions = small_rnn_model.sample(features)
  sample_captions = decode_captions(sample_captions, data['idx_to_word'])

  for gt_caption, sample_caption, url in zip(gt_captions, sample_captions, urls):
    plt.imshow(image_from_url(url))
    plt.title('%s\n%s\nGT:%s' % (split, sample_caption, gt_caption))
    plt.axis('off')
    plt.show()
